# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_IN = PROJECT_ROOT / "data" / "input" / "state.0000000000.upper.nc"
DATA_PROC = PROJECT_ROOT / "data" / "processed"
RESULTS = PROJECT_ROOT / "results"

from src.fieldset import summarize_dataset, preview_input_fields
from src.run import RunConfig, run_parcels_experiment, load_trajectories
from src.metrics_dispersion import absolute_dispersion, pair_dispersion
from src.metrics_clustering import nearest_neighbor_metric, voronoi_metrics
from src.metrics_patchiness import density_map_metrics
from src.io_utils import ensure_dir

# %%
summary = summarize_dataset(DATA_IN)
summary
# Out:
# {'path': 'C:\\Users\\Jelle Gortemaker\\Documents\\Thesis\\parcels_postprocessing\\data\\input\\state.0000000000.upper.nc',
#  'dims': {'T': 30, 'Zmd000059': 2, 'Y': 384, 'Xp1': 385, 'Yp1': 385, 'X': 384},
#  'coords': ['Xp1', 'Y', 'X', 'Yp1', 'T', 'iter'],
#  'data_vars': ['UVEL', 'VVEL'],
#  'x_name': 'X',
#  'y_name': 'Y',
#  'time_name': 'T',
#  'depth_name': None,
#  'u_name': 'UVEL',
#  'v_name': 'VVEL',
#  'is_3d': False}

# %%
ds_preview = preview_input_fields(DATA_IN, surface_only=True)
ds_preview
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jelle Gortemaker\miniconda3\envs\thesis_parcels\Lib\site-packages\xarray\core\dataarray.py:881, in DataArray._getitem_coord(self, key)
#     880 try:
# --> 881     var = self._coords[key]
#     882 except KeyError:
#
# KeyError: 'x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds_preview = preview_input_fields(DATA_IN, surface_only=True)
#       2 ds_preview
#
# File ~\Documents\Thesis\parcels_postprocessing\src\fieldset.py:169, in preview_input_fields(path, surface_only)
#     168 def preview_input_fields(path: str | Path, surface_only: bool = True) -> xr.Dataset:
# --> 169     _, _, ds = build_fieldset(path, surface_only=surface_only)
#     170     return ds
#
# ...
